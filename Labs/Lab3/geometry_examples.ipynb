# %% [markdown]
# # Examples of the Geometry Classes

# %%
from circle import Circle
from rectangle import Rectangle
from sphere import Sphere
from cube import Cube

# %% [markdown]
# ## Examples of the Circle Class

# %%
circ = Circle(2.5, 3, -3)
print(circ)
print(f"The area of the circle is: {circ.area():.1f} units.")
print(f"The circumference of the circle is: {circ.circumference():.1f} length units.")
print(f"Is the point (2, -2) inside the circle? Answer: {circ.is_inside(2, -2)}.")
# Out:
# The radius of the circle is: 2.5 length units. The geometric center is: (3, -3).
# The area of the circle is: 19.6 units.
# The circumference of the circle is: 15.7 length units.
# Is the point (2, -2) inside the circle? Answer: True.

# %%
#Plots the circle and the point that was tested with the is_inside-function (above).
circ.plot_figure(fixed_scale10=True, point=(2, -2))

# %%
#Uses the translate-function to move the circle.
circ.translate(-7, 7)
print(circ)
print(f"Is the point (2, -2) inside the circle? Answer: {circ.is_inside(2, -2)}.")
# Out:
# The radius of the circle is: 2.5 length units. The geometric center is: (-7, 7).
# Is the point (2, -2) inside the circle? Answer: False.

# %%
#Plots the circle that was moved.
circ.plot_figure(fixed_scale10=True, point=(2, -2))

# %%
#If the edges of a circle is outside the range -10 to 10 (or/and the fixed_scale10 is False), this is the resulting plot.
circ2 = Circle(5, -10, 15)
circ2.plot_figure()

# %% [markdown]
# ## Examples of the Rectangle Class

# %%
rect = Rectangle(4, 3, 3, -3)
print(rect)
print(f"The area of the rectangle is: {rect.area()} units.")
print(f"The circumference of the rectangle is: {rect.circumference()} length units.")
print(f"Is the point (2, -2) inside the rectangle? Answer: {rect.is_inside(2, -2)}.")
# Out:
# The length of the rectangle is 4 length units, and the width is 3 length units. The geometric center is: (3, -3).
# The area of the rectangle is: 12 units.
# The circumference of the rectangle is: 14 length units.
# Is the point (2, -2) inside the rectangle? Answer: True.

# %%
#Plots the rectangle and the point that was tested with the is_inside-function (above).
rect.plot_figure(fixed_scale10=True, point=(2, -2))

# %%
#Uses the translate-function to move the rectangle.
rect.translate(-7, 7)
print(rect)
print(f"Is the point (2, -2) inside the rectangle? Answer: {rect.is_inside(2, -2)}.")
# Out:
# The length of the rectangle is 4 length units, and the width is 3 length units. The geometric center is: (-7, 7).
# Is the point (2, -2) inside the rectangle? Answer: False.

# %%
#Plots the rectangle that was moved.
rect.plot_figure(fixed_scale10=True, point=(2, -2))

# %%
#If the edges of a rectangle is outside the range -10 to 10 (or/and the fixed_scale10 is False), this is the resulting plot.
rect2 = Rectangle(7, 8, -17, 19)
rect2.plot_figure()

# %% [markdown]
# ## Examples of the Sphere Class

# %%
sph = Sphere(3, 3, -3, 3)
print(sph)
print(f"The surface area of the sphere is: {sph.area():.1f} units.")
print(f"The circumference of the sphere is: {sph.circumference():.1f} length units.")
print(f"The volume of the sphere is: {sph.volume():.1f} units.")
print(f"Is the point (4, -3.5, 4) inside the sphere? Answer: {sph.is_inside(4, -3.5, 4)}.")
# Out:
# The radius of the sphere is: 3 length units. The geometric center is: (3, -3, 3).
# The surface area of the sphere is: 113.1 units.
# The circumference of the sphere is: 18.8 length units.
# The volume of the sphere is: 113.1 units.
# Is the point (4, -3.5, 4) inside the sphere? Answer: True.

# %%
#Plots the sphere and the point that was tested with the is_inside-function (above).
sph.plot_figure(fixed_scale10=True, point=(4, -3.5, 4))

# %%
#Uses the translate-function to move the sphere.
sph.translate(-7, 7, 7)
print(sph)
print(f"Is the point (4, -3.5, 4) inside the sphere? Answer: {sph.is_inside(4, -3.5, 4)}.")
# Out:
# The radius of the sphere is: 3 length units. The geometric center is: (-7, 7, 7).
# Is the point (4, -3.5, 4) inside the sphere? Answer: False.

# %%
#Plots the sphere that was moved.
sph.plot_figure(fixed_scale10=True, point=(4, -3.5, 4))

# %%
#If the edges of the sphere is outside the range -10 to 10 (or/and the fixed_scale10 is False), this is the resulting plot.
sph2 = Sphere(5, -10, 15, 5)
sph2.plot_figure()

# %% [markdown]
# ## Examples of the Cube Class

# %%
cub = Cube(3, 3, -3, 3)
print(cub)
print(f"The surface area of the cube is: {cub.area():.1f} units.")
print(f"The circumference of the cube is: {cub.circumference():.1f} length units.")
print(f"The volume of the cube is: {cub.volume():.1f} units.")
print(f"Is the point (4, -3.5, 4) inside the cube? Answer: {cub.is_inside(4, -3.5, 4)}.")
# Out:
# The cube has a side of 3 length units. The geometric center is: (3, -3, 3).
# The surface area of the cube is: 54.0 units.
# The circumference of the cube is: 12.0 length units.
# The volume of the cube is: 27.0 units.
# Is the point (4, -3.5, 4) inside the cube? Answer: True.

# %%
#Plots the cube and the point that was tested with the is_inside-function (above).
cub.plot_figure(fixed_scale10=True, point=(4, -3.5, 4))

# %%
#Uses the translate-function to move the cube.
cub.translate(-8.5, -8.5, -8.5)
print(cub)
print(f"Is the point (4, -3.5, 4) inside the sphere? Answer: {cub.is_inside(4, -3.5, 4)}.")
# Out:
# The cube has a side of 3 length units. The geometric center is: (-8.5, -8.5, -8.5).
# Is the point (4, -3.5, 4) inside the sphere? Answer: False.

# %%
#Plots the cube that was moved.
cub.plot_figure(fixed_scale10=True, point=(4, -3.5, 4))

# %%
#If the edges of a cube is outside the range -10 to 10 (or/and the fixed_scale10 is False), this is the resulting plot.
cub2 = Cube(8, -6, 15, 5)
cub2.plot_figure()

# %% [markdown]
# ## Examples of Comparing the Classes

# %%
cub3 = Cube(8, -3, 4, 5)

print(f"Is a rectangle with {rect.length} in length and {rect.width} in width, equal to a circle with a radius of {circ.radius}? Answer: {rect == circ}.")
print(f"Is a sphere with a radius of {sph.radius}, equal to a cube with a side of {cub.side}? Answer: {sph == cub}.")
print(f"Is a cube with a side of {cub.side} and coordinates ({cub.x_coordinate}, {cub.y_coordinate}, {cub.z_coordinate}), equal to a cube with a side of {cub2.side} and coordinates ({cub2.x_coordinate}, {cub2.y_coordinate}, {cub2.z_coordinate})? Answer: {cub == cub2}.")
print(f"Is a cube with a side of {cub2.side} and coordinates ({cub2.x_coordinate}, {cub2.y_coordinate}, {cub2.z_coordinate}), equal to a cube with a side of {cub3.side} and coordinates ({cub3.x_coordinate}, {cub3.y_coordinate}, {cub3.z_coordinate})? Answer: {cub2 == cub3}.")
# Out:
# Is a rectangle with 4 in length and 3 in width, equal to a circle with a radius of 2.5? Answer: False.
# Is a sphere with a radius of 3, equal to a cube with a side of 3? Answer: False.
# Is a cube with a side of 3 and coordinates (-8.5, -8.5, -8.5), equal to a cube with a side of 8 and coordinates (-6, 15, 5)? Answer: False.
# Is a cube with a side of 8 and coordinates (-6, 15, 5), equal to a cube with a side of 8 and coordinates (-3, 4, 5)? Answer: True.
